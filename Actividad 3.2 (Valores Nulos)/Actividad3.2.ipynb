# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('listings.csv')
df.head()
# Out:
#       id           source                                            name  \
# 0  27934      city scrape                 Nice room with superb city view
# 1  27979  previous scrape                  Easy going landlord,easy place
# 2  28745  previous scrape               modern-style apartment in Bangkok
# 3  35780      city scrape  Spacious one bedroom at The Kris Condo Bldg. 3
# 4  48736      city scrape                 Condo with Chaopraya River View
#
#                                          description  \
# 0  Our cool and comfortable one bedroom apartment...
# 1                                                NaN
# 2  A modern-style apartment situated in a cool ne...
# 3  Cozy and clean apartment at MRT Sutthisarn sta...
# 4  at a size of 25sqm for your vacation in BKK.<b...
#
#                                neighborhood_overview  host_id   host_name  \
# 0  It is very center of Bangkok and easy access t...   120437      Nuttee
# ...

# %%
df = pd.read_csv('listings.csv',index_col=0)
df
# Out:
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# 28745                             modern-style apartment in Bangkok
# 35780                Spacious one bedroom at The Kris Condo Bldg. 3
# 48736                               Condo with Chaopraya River View
# ...                                                             ...
# ...

# %%
valores_nulos =df.isnull().sum()
valores_nulos
# Out:
# source                             0
# name                               0
# description                      954
# neighborhood_overview          14919
# host_id                            0
# host_name                          1
# host_since                         0
# host_location                   6148
# host_about                     10539
# host_response_time              4894
# host_response_rate              4894
# host_acceptance_rate            4348
# host_is_superhost               1195
# host_listings_count                0
# host_total_listings_count          0
# host_verifications                 0
# host_identity_verified             0
# neighbourhood_cleansed             0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms_text                   124
# bedrooms                        1299
# ...

# %%
valores_nulos =df.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(150878)

# %%
data3 = df.copy()

# %%
data3["description"] = data3["description"].fillna(method="ffill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\2275716144.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["description"] = data3["description"].fillna(method="ffill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                             0
# name                               0
# description                        0
# neighborhood_overview          14919
# host_id                            0
# host_name                          1
# host_since                         0
# host_location                   6148
# host_about                     10539
# host_response_time              4894
# host_response_rate              4894
# host_acceptance_rate            4348
# host_is_superhost               1195
# host_listings_count                0
# host_total_listings_count          0
# host_verifications                 0
# host_identity_verified             0
# neighbourhood_cleansed             0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms_text                   124
# bedrooms                        1299
# ...

# %%
data3["neighborhood_overview"] = data3["neighborhood_overview"].fillna(method="ffill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\421091148.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["neighborhood_overview"] = data3["neighborhood_overview"].fillna(method="ffill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                             0
# name                               0
# description                        0
# neighborhood_overview              0
# host_id                            0
# host_name                          1
# host_since                         0
# host_location                   6148
# host_about                     10539
# host_response_time              4894
# host_response_rate              4894
# host_acceptance_rate            4348
# host_is_superhost               1195
# host_listings_count                0
# host_total_listings_count          0
# host_verifications                 0
# host_identity_verified             0
# neighbourhood_cleansed             0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms_text                   124
# bedrooms                        1299
# ...

# %%
data3["host_name"] = data3["host_name"].fillna(method="ffill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\3378329512.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["host_name"] = data3["host_name"].fillna(method="ffill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                             0
# name                               0
# description                        0
# neighborhood_overview              0
# host_id                            0
# host_name                          0
# host_since                         0
# host_location                   6148
# host_about                     10539
# host_response_time              4894
# host_response_rate              4894
# host_acceptance_rate            4348
# host_is_superhost               1195
# host_listings_count                0
# host_total_listings_count          0
# host_verifications                 0
# host_identity_verified             0
# neighbourhood_cleansed             0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms_text                   124
# bedrooms                        1299
# ...

# %%
data3["host_location"] = data3["host_location"].fillna(method="bfill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\2250728545.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["host_location"] = data3["host_location"].fillna(method="bfill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                             0
# name                               0
# description                        0
# neighborhood_overview              0
# host_id                            0
# host_name                          0
# host_since                         0
# host_location                      0
# host_about                     10539
# host_response_time              4894
# host_response_rate              4894
# host_acceptance_rate            4348
# host_is_superhost               1195
# host_listings_count                0
# host_total_listings_count          0
# host_verifications                 0
# host_identity_verified             0
# neighbourhood_cleansed             0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms_text                   124
# bedrooms                        1299
# ...

# %%
data3["host_about"] = data3["host_about"].fillna(method="ffill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\3780886237.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["host_about"] = data3["host_about"].fillna(method="ffill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time             4894
# host_response_rate             4894
# host_acceptance_rate           4348
# host_is_superhost              1195
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                  124
# bedrooms                       1299
# beds                           4984
# ...

# %%
data3["host_response_time"] = data3["host_response_time"].fillna(method="ffill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\3985737599.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["host_response_time"] = data3["host_response_time"].fillna(method="ffill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate             4894
# host_acceptance_rate           4348
# host_is_superhost              1195
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                  124
# bedrooms                       1299
# beds                           4984
# ...

# %%
data3["host_response_rate"] = data3["host_response_rate"].fillna(method="bfill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\3542542608.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["host_response_rate"] = data3["host_response_rate"].fillna(method="bfill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate           4348
# host_is_superhost              1195
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                  124
# bedrooms                       1299
# beds                           4984
# ...

# %%
data3["host_acceptance_rate"] = data3["host_acceptance_rate"].fillna(method="bfill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\1267690678.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["host_acceptance_rate"] = data3["host_acceptance_rate"].fillna(method="bfill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost              1195
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                  124
# bedrooms                       1299
# beds                           4984
# ...

# %%
data3["host_is_superhost"] = data3["host_is_superhost"].fillna(method="ffill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\184147736.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["host_is_superhost"] = data3["host_is_superhost"].fillna(method="ffill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                  124
# bedrooms                       1299
# beds                           4984
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25079 entries, 27934 to 1252486847996346909
# Data columns (total 49 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   source                       25079 non-null  object
#  1   name                         25079 non-null  object
#  2   description                  25079 non-null  object
#  3   neighborhood_overview        25079 non-null  object
#  4   host_id                      25079 non-null  int64
#  5   host_name                    25079 non-null  object
#  6   host_since                   25079 non-null  object
#  7   host_location                25079 non-null  object
#  8   host_about                   25079 non-null  object
#  9   host_response_time           25079 non-null  object
#  10  host_response_rate           25079 non-null  object
#  11  host_acceptance_rate         25079 non-null  object
# ...

# %%
data3["bathrooms_text"] = data3["bathrooms_text"].fillna(method="ffill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\161176930.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["bathrooms_text"] = data3["bathrooms_text"].fillna(method="ffill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                       1299
# beds                           4984
# ...

# %%
data3["bedrooms"] = data3["bedrooms"].fillna(round(df["bedrooms"].mean(),1))
data3
# Out:
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# 28745                             modern-style apartment in Bangkok
# 35780                Spacious one bedroom at The Kris Condo Bldg. 3
# 48736                               Condo with Chaopraya River View
# ...                                                             ...
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                           4984
# ...

# %%
data3["beds"] = data3["beds"].fillna(round(df["beds"].mean(),1))

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["price"] = data3["price"].fillna("$2480")
data3
# Out:
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# 28745                             modern-style apartment in Bangkok
# 35780                Spacious one bedroom at The Kris Condo Bldg. 3
# 48736                               Condo with Chaopraya River View
# ...                                                             ...
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["has_availability"] = data3["has_availability"].fillna(method="ffill")
data3
# Out:
# C:\Users\issei\AppData\Local\Temp\ipykernel_37456\2216306814.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["has_availability"] = data3["has_availability"].fillna(method="ffill")
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["first_review"] = data3["first_review"].fillna("2025-01-24")
data3
# Out:
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# 28745                             modern-style apartment in Bangkok
# 35780                Spacious one bedroom at The Kris Condo Bldg. 3
# 48736                               Condo with Chaopraya River View
# ...                                                             ...
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["last_review"] = data3["last_review"].fillna("2025-01-24")
data3
# Out:
#                               source  \
# id
# 27934                    city scrape
# 27979                previous scrape
# 28745                previous scrape
# 35780                    city scrape
# 48736                    city scrape
# ...                              ...
# 1252462451305524959      city scrape
# 1252465334122867402      city scrape
# 1252478699202812971      city scrape
# 1252484092218301658      city scrape
# 1252486847996346909      city scrape
#
#                                                                name  \
# id
# 27934                               Nice room with superb city view
# 27979                                Easy going landlord,easy place
# 28745                             modern-style apartment in Bangkok
# 35780                Spacious one bedroom at The Kris Condo Bldg. 3
# 48736                               Condo with Chaopraya River View
# ...                                                             ...
# ...

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["review_scores_rating"] = data3["review_scores_rating"].fillna(round(df["review_scores_rating"].mean(),1))

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["review_scores_accuracy"] = data3["review_scores_accuracy"].fillna(round(df["review_scores_accuracy"].mean(),1))

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["review_scores_cleanliness"] = data3["review_scores_cleanliness"].fillna(round(df["review_scores_cleanliness"].mean(),1))

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["review_scores_checkin"] = data3["review_scores_checkin"].fillna(round(df["review_scores_checkin"].mean(),1))

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["review_scores_communication"] = data3["review_scores_communication"].fillna(round(df["review_scores_communication"].mean(),1))

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["review_scores_location"] = data3["review_scores_location"].fillna(round(df["review_scores_location"].mean(),1))

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["review_scores_value"] = data3["review_scores_value"].fillna(round(df["review_scores_value"].mean(),1))

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                            0
# name                              0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# ...

# %%
data3["reviews_per_month"] = data3["reviews_per_month"].fillna(round(df["reviews_per_month"].mean(),1))

# %%
valores_nulos =data3.isnull().sum()
valores_nulos
# Out:
# source                         0
# name                           0
# description                    0
# neighborhood_overview          0
# host_id                        0
# host_name                      0
# host_since                     0
# host_location                  0
# host_about                     0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_listings_count            0
# host_total_listings_count      0
# host_verifications             0
# host_identity_verified         0
# neighbourhood_cleansed         0
# latitude                       0
# longitude                      0
# property_type                  0
# room_type                      0
# accommodates                   0
# bathrooms_text                 0
# bedrooms                       0
# beds                           0
# amenities                      0
# price                          0
# ...

# %%
data3.to_csv("Pais_Sin_Nulos.csv")
